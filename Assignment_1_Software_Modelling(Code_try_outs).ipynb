# %% [markdown]
# <a href="https://colab.research.google.com/github/Shahad-AlAli/Assignemnt-1-Software-Modelling/blob/main/Assignment_1_Software_Modelling(Code_try_outs).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from enum import Enum
class Gender(Enum):
  Male=1
  Female=2

class Person: 
    def __init__(self, firstName, lastName, cellPhoneNumber, gender, age):
        self.firstName = firstName
        self.lastName = lastName
        self.cellPhoneNumber = cellPhoneNumber
        self.gender = gender
        self.age = age
        
    def setFirstName(self, firstName):
        self.firstName = firstName
    def getFirstName():
        return self.firstName
    def setlastName(self, lastName):
        self.lastName = lastName
    def getlastName():
        return self.lastName
    def setcellPhoneNumber(self, cellPhoneNumber):
        self.cellPhoneNumber = cellPhoneNumber
    def getcellPhoneNumber():
        return self.cellPhoneNumber
    def setgender(self, gender):
        self.gender = gender
    def getgender():
        return self.gender
    def setage(self, age):
        self.age = age
    def getage():
        return self.age
    
    def __str__(self):
        return "First Name: "+self.firstName+", Last Name: "+self.lastName+", Cell Phone Number:"+self.cellPhoneNumber+", Gender: " +self.gender+ " , Age: "+self.age

# %%
from enum import Enum
class PaymentMethod(Enum):
  cash=1
  creditCard=2
class Address(Enum):
  AbuDhabi=1
  Dubai=2
  Sharjah=3
  Ajman=4
  UmmAlQuwain=5
  RasAlKhaimah=6
  Fujairah=7
  
class Customer(Person):
    def __init__(self, firstName, lastName, cellPhoneNumber, gender, age, ID, email, paymentMethod, address, appointmentDate):
        Person.__init__(self, firstName, lastName, cellPhoneNumber, gender, age)
        self.ID = ID
        self.email = email
        self.paymentMethod = paymentMethod
        self.address = address
        self.appointmentDate = appointmentDate
        
    def __str__(self):
        return Person.__str__(self) + ", ID: "+self.ID+ ", email:" +self.email+ ", Payment Method:" +self.paymentMethod+ ", Address:" +self.address+ ", Appointment Date:" +self.appointmentDate

# %%
Hazza = Customer("Hazza", "Al Naqbi", "+971506672889", "Male", "21", "784-2002-1234567-0", "Hazza2002@gmail.com", "creditCard","UmmAlQuwain","15/3/2023")
print(Hazza)
# Out:
# First Name: Hazza, Last Name: Al Naqbi, Cell Phone Number:+971506672889, Gender: Male , Age: 21, ID: 784-2002-1234567-0, email:Hazza2002@gmail.com, Payment Method:creditCard, Address:UmmAlQuwain, Appointment Date:15/3/2023

# %%
from enum import Enum
class Diagnostics(Enum):
  codeReader=15
  OBDScanners=20
class OilReplacment(Enum):
  Yes=120
  No=0
class OilFilterParts(Enum):
  Yes=35
  No=0
class TireReplacment(Enum):
  Onetire=50
  Twotires=100
  Threetires=150
  Fourtires=200
  Sixtires=300

class Tire(Enum):
  Onetire=80
  Twotires=160
  Threetires=240
  Fourtires=320
  Sixtires=480

class Services:
  def __init__(self, diagnostics, oilReplacement, oilFilterParts, tireReplacment, tire):
    self.diagnostics = diagnostics
    self.oilReplacement = oilReplacement
    self.oilFilterParts = oilFilterParts
    self.tireReplacment = tireReplacment
    self.tire = tire

  def setdiagnostics(self, diagnostics):
    self.diagnostics = diagnostics
  def getdiagnostics():
    return self.diagnostics.value
  def setoilReplacement(self, oilReplacement):
    self.oilReplacement = oilReplacement
  def getoilReplacement():
    return self.oilReplacement.value
  def setoilFilterParts(self, oilFilterParts):
    self.oilFilterParts = oilFilterParts
  def getoilFilterParts():
    return self.oilFilterParts.value
  def settireReplacment(self, tireReplacment):
    self.tireReplacment = tireReplacment
  def gettireReplacment():
    return self.tireReplacment.value
  def settire(self, tire):
    self.tire = tire
  def gettire():
    return self.tire.value

# %%
class Garage:
    def __init__(self, Customer, Services):
        self.customer = customer
        self.services = Services(Diagnostics.codeReader, OilRepacement.Yes, OilFilterParts.Yes, TireReplacement.TwoTires, Tire.TwoTires)

    def TotalCost(self):
        total = 0
        total += self.services.getDiagnostics()
        total += self.services.getOilReplacement()
        total += self.services.getOilFilterParts()
        total += self.services.getTireReplacement()
        total += self.services.getTire()
        return total

my_garage = Garage(customer)
total_cost = my_garage.TotalCost()
print(total_cost)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-664cc5fddbe5> in <module>
#      13         return total
#      14
# ---> 15 my_garage = Garage(customer)
#      16 total_cost = my_garage.TotalCost()
#      17 print(total_cost)
#
# NameError: name 'customer' is not defined

# %%
from enum import Enum
class VehicleType(Enum):
  Nissan=1
  Toyota=2
  Mercedes=3
  Audi=4
  BMW=5
class VehicleColor(Enum):
  White=1
  Black=2
  Silver=3
  Gray=4
  Red=5

class Vehicle:
  def __init__(self, vehicleType, vehicleName, vehicleColor, vehicleID, vehicleYear):
        self.vehicleType = vehicleType
        self.vehicleName = vehicleName
        self.vehicleColor = vehicleColor
        self.vehicleID = vehicleID
        self.vehicleYear = vehicleYear

  def setvehicleType(self, vehicleType):
    self.vehicleType = vehicleType
  def getvehicleType():
    return self.vehicleType
  def setvehicleName(self, vehicleName):
    self.vehicleName = vehicleName
  def getvehicleName():
    return self.vehicleName
  def setvehicleColor(self, vehicleColor):
    self.vehicleColor = vehicleColor
  def getvehicleColor():
    return self.vehicleColor
  def setvehicleID(self, vehicleID):
    self.tireReplacment = vehicleID
  def getvehicleID():
    return self.vehicleID
  def setvehicleYear(self, vehicleYear):
    self.vehicleYear = vehicleYear
  def getvehicleYear():
    return self.vehicleYear

# %%
from enum import Enum
class Gender(Enum):
    Male = 1
    Female = 2


class Person:
    def __init__(self, firstName, lastName, cellPhoneNumber, gender, age):
        self.firstName = firstName
        self.lastName = lastName
        self.cellPhoneNumber = cellPhoneNumber
        self.gender = gender
        self.age = age

    def setFirstName(self, firstName):
        self.firstName = firstName
    def getFirstName(self):
        return self.firstName
    def setlastName(self, lastName):
        self.lastName = lastName
    def getlastName(self):
        return self.lastName
    def setcellPhoneNumber(self, cellPhoneNumber):
        self.cellPhoneNumber = cellPhoneNumber
    def getcellPhoneNumber(self):
        return self.cellPhoneNumber
    def setgender(self, gender):
        self.gender = gender
    def getgender(self):
        return self.gender
    def setage(self, age):
        self.age = age
    def getage(self):
        return self.age

    def __str__(self):
        return ("First Name: "+ self.firstName+ ", Last Name: "+ self.lastName+ ", Cell Phone Number:"+ self.cellPhoneNumber+ ", Gender: "+ self.gender.name+ " , Age: "+ str(self.age))


class PaymentMethod(Enum):
    cash = 1
    creditCard = 2


class Address(Enum):
    AbuDhabi = 1
    Dubai = 2
    Sharjah = 3
    Ajman = 4
    UmmAlQuwain = 5
    RasAlKhaimah = 6
    Fujairah = 7


class Customer(Person):
    def __init__(self, firstName, lastName, cellPhoneNumber, gender, age, ID, email, paymentMethod, address, appointmentDate):
        Person.__init__(self, firstName, lastName, cellPhoneNumber, gender, age)
        self.ID = ID
        self.email = email
        self.paymentMethod = paymentMethod
        self.address = address
        self.appointmentDate = appointmentDate

    def __str__(self):
      return Person.__str__(self) + ", ID: "+self.ID+ ", email:" +self.email+ ", Payment Method:" +self.paymentMethod+ ", Address:" +self.address+ ", Appointment Date:" +self.appointmentDate

class VehicleType(Enum):
    Nissan = 1
    Toyota = 2
    Mercedes = 3
    Audi = 4
    BMW = 5


class VehicleColor(Enum):
    White = 1
    Black = 2
    Silver = 3
    Gray = 4
    Red = 5


class Vehicle:
    def __init__(self, vehicleType, vehicleName, vehicleColor, vehicleID, vehicleYear):
        self.vehicleType = vehicleType
        self.vehicleName = vehicleName
        self.vehicleColor = vehicleColor
        self.vehicleID = vehicleID
        self.vehicleYear = vehicleYear

    def setvehicleType(self, vehicleType):
        self.vehicleType = vehicleType
    def getvehicleType(self):
        return self.vehicleType
    def setvehicleName(self, vehicleName):
        self.vehicleName = vehicleName
    def getvehicleName(self):
        return self.vehicleName
    def setvehicleColor(self, vehicleColor):
        self.vehicleColor = vehicleColor
    def getvehicleColor(self):
        return self.vehicleColor
    def setvehicleID(self, vehicleID):
        self.vehicleID = vehicleID
    def getvehicleID(self):
        return self.vehicleID
    def setvehicleYear(self, vehicleYear):
        self.vehicleYear = vehicleYear
    def getvehicleYear(self):
        return self.vehicleYear

    def __str__(self):
      return Vehicle.__str__(self) + ", Vehicle Type: "+self.vehicleType+ ", Vehicle Name:" +self.vehicleName+ ", Vehicle Color:" +self.vehicleColor+ ", Vehicle ID:" +self.vehicleID+ ", Vehicle Year:" +self.vehicleYear


class Diagnostics(Enum):
    CodeReader = 15
    OBDScanners = 20


class OilReplacement(Enum):
    Yes = 120
    No = 0


class OilFilterParts(Enum):
    Yes = 35
    No = 0


class TireReplacement(Enum):
    OneTire = 50
    TwoTires = 100
    ThreeTires = 150
    FourTires = 200
    SixTires = 300


class Tire(Enum):
    OneTire = 80
    TwoTires = 160
    ThreeTires = 240
    FourTires = 320
    SixTires = 480


class Services:
    def __init__(self, diagnostics, oilReplacement, oilFilterParts, tireReplacement, tire):
        self.diagnostics = diagnostics
        self.oilReplacement = oilReplacement
        self.oilFilterParts = oilFilterParts
        self.tireReplacement = tireReplacement
        self.tire = tire

    def setDiagnostics(self, diagnostics):
        self.diagnostics = diagnostics
    def getDiagnostics(self):
        return self.diagnostics.value
    def setOilReplacement(self, oilReplacement):
        self.oilReplacement = oilReplacement
    def getOilReplacement(self):
        return self.oilReplacement.value
    def setOilFilterParts(self, oilFilterParts):
        self.oilFilterParts = oilFilterParts
    def getOilFilterParts(self):
        return self.oilFilterParts.value
    def setTireReplacement(self, tireReplacement):
        self.tireReplacement = tireReplacement
    def getTireReplacement(self):
        return self.tireReplacement.value
    def setTire(self, tire):
        self.tire = tire
    def getTire(self):
        return self.tire.value
    
    def __str__(self):
      return Services.__str__(self)+(Diagnostics.codeReader, OilReplacment.Yes, OilFilterParts.Yes, TireReplacment.TwoTires, Tire.TwoTires)

    #def TotalCost(self):
        #total = 0
        #total += self.services.getdiagnostics()
        #total += self.services.getoilReplacement()
        #total += self.services.getoilFilterParts()
        #total += self.services.gettireReplacment()
        #total += self.services.gettire()
        #return total

    #def __str__(self):
      #return TotalCost.__str__(self)+(Diagnostics.codeReader, OilReplacment.Yes, OilFilterParts.Yes, TireReplacment.TwoTires, Tire.TwoTires)
